# %%
import pandas as pd

pages = ['https://www.teamrankings.com/nfl/stat/points-per-game']

for x in pages:
    site = x #the site I want to scrape
    stat = site.rsplit('/', 1)[1] #this saves the text after the last slash in the URL so I can use it for my filenames
    df = pd.read_html(site,header=0,index_col=0)[0] #reading in the site
    df2 = df[['Team','2022']]
    df2.columns = ['Team','2021 '+stat]
    #df[0].to_csv("%s.csv" % stat) #saving the file as a csv using the stat variable in the filename
df2
# Out:
#                Team  2021 points-per-game
# Rank
# 1       Kansas City                  29.6
# 2           Buffalo                  27.8
# 3      Philadelphia                  27.5
# 4           Seattle                  26.5
# 5        Cincinnati                  25.9
# 6             Miami                  25.6
# 7            Dallas                  25.4
# 8           Detroit                  25.0
# 8         Baltimore                  25.0
# 10        Las Vegas                  24.1
# 11        Cleveland                  23.9
# 12        Minnesota                  23.8
# 13      LA Chargers                  22.9
# 14          Atlanta                  22.7
# 15    San Francisco                  22.6
# 16     Jacksonville                  22.2
# 17          Arizona                  22.0
# 18          Chicago                  20.9
# 19          NY Jets                  20.9
# 20      New Orleans                  20.8
# 20      New England                  20.8
# ...

# %%
import pandas as pd

site = 'https://www.teamrankings.com/nfl/stat/points-per-game' #the site I want to scrape
stat = site.rsplit('/', 1)[1] #this saves the text after the last slash in the URL so I can use it for my filenames
df = pd.read_html(site,index_col=['Rank','Team','2022']) #reading in the site
df[0].to_csv("%s.csv" % stat) #saving the file as a csv using the stat variable in the filename
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/dj/5z27l73x17j08dg75tzx2dw00000gn/T/ipykernel_6567/4242606532.py in <module>
#       6 stat = site.rsplit('/', 1)[1] #this saves the text after the last slash in the URL so I can use it for my filenames
#       7 df = pd.read_html(site,index_col=0) #reading in the site
# ----> 8 df2 = df.columns(['Rank','Team','2022'])
#
# AttributeError: 'list' object has no attribute 'columns'
